# %% [markdown]
# # Comments in Python

# %% [markdown]
#     comments are used to explain code or make notes. They are ignored by the Python interpreter.
#
#     Types of comments:
#     1. single line comment: represented by # symbol
#     2. multiline comment: represented by triple quotes (''' or """),These are often used to write detailed explanations or temporarily block sections of code:

# %%
# 10+30
'''comments are used to explain code or make notes. They are ignored by the Python interpreter.
    comments are used to explain code or make notes. They are ignored by the Python interpreter.
    comments are used to explain code or make notes. They are ignored by the Python interpreter.'''
print(type("hello"))    # checking type
# Out:
# <class 'str'>

# %% [markdown]
#  # Multiple Print Statements

# %% [markdown]
#     print() function is used to display output in console

# %% [markdown]
#     print syntax: print(*objects, sep=' ', end='\n', file=None, flush=False)
#     objects- what to print
#     sep= specifices what to print between multiple values
#     end= ending charator= defult it take newline \n

# %%
# print("apple","kiwi",sep=" - ")

print("global warming",end=" ")
print("in the world")
# Out:
# global warming in the world

# %%
name="riya"
grade= 10
print("Im ",name,"Studying in ",grade,"grade")
# Out:
# Im  riya Studying in  10 grade

# %%
# f string formatting 
name="riya"
grade= 10
print(f"Im {name} studying in {grade} grade")
# Out:
# Im riya studying in 10 grade

# %%
# format
name="riya"
grade= 10
print("Im {} studying in {} grade".format(name,grade))
# Out:
# Im riya studying in 10 grade

# %% [markdown]
# | Specifier | Meaning                     | Example   |
# | --------- | --------------------------- | --------- |
# | `%s`      | String                      | `"Alice"` |
# | `%d`      | Integer                     | `20`      |
# | `%f`      | Floating-point number       | `99.99`   |
# | `%.2f`    | Float with 2 decimal places | `99.99`   |
# | `%c`      | Single character            | `'A'`     |

# %%
name="riya"
grade= 10
score= 78.456
print("Im %s studying in %d grade,scored %.5f" %(name,grade,score))
# Out:
# Im riya studying in 10 grade,scored 78.45600

# %% [markdown]
# Escape Sequences
#
#     Escape sequences are special characters in strings that start with a backslash (\). They are used to represent certain special characters.
#
#     Some commonly used escape sequences:
#
#     \n: New line
#     \t: Tab space
#     \\: Backslash
#     \': Single Qoute

# %%
print("hello\nworld ")
print("hello\t\t\tworld ")       
print("hello\\world ")   

print("\'helloworld\' ")
# Out:
# hello
# world
# hello			world
# hello\world
# 'helloworld'

# %% [markdown]
# # input and output funations
#     input() function to take input from the user. The data entered by the user is always received as a string, so if you want to use it as
#     a different data type (e.g., integer or float), you'll need to convert it using type conversion functions like int() or float().

# %%
name= input("enter your name: ")
grade= input("enter your grade: ")

# print("My name is ",name,"studying in ",grade,"grade")
print("My name is "+name,"studying in " + grade +"grade")
# Out:
# My name is riya studying in 10grade

# %%
name= input("enter your name: ")
grade= int(input("enter your grade: "))
print("My name is "+name,"studying in " + str(grade) +" grade")
# Out:
# My name is riya studying in 10grade

# %% [markdown]
# # String Manipulation
#     Strings are sequences of characters. Python provides many useful methods to manipulate strings.
#
#     Common String Operations:
#     Concatenation: Joining two or more strings together using the + operator.
#     first_name = "John"
#     last_name = "Doe"
#     full_name = first_name + " " + last_name
#     print(full_name)  # Output: "John Doe"
#
#     Repetition: Repeating a string multiple times using the * operator.
#     greeting = "Hello! " * 3
#     print(greeting)  # Output: "Hello! Hello! Hello! "

# %%
greeting= "hello"*3
greeting
print("="*60)

# %% [markdown]
# # Operators in Python
#
#     Types of Operators
#     1. Arithematic operators:  Mathematical calculations
#     2. Comparison (Relational) Operators: Compare values
#     3. Assignment Operators:  Assign or update values
#     4. Logical Operators: Combine conditions
#     5. Bitwise Operators: Operate on binary values
#     6. Membership Operators: Check if a value exists in a sequence
#     7. Identity Operators: Check if two variables refer to the same object

# %%
x=10

# %% [markdown]
# # Arithematic operators
#
#     Assignment operators are used to assign values to variables. The simplest one is = which assigns the value on the right to the variable on the left. There are also compound assignment operators that combine arithmetic operations with assignment.
#
#     Common Assignment Operators:
#     =: Assigns value on the right to the variable on the left.
#     +: Addition
#     -:Subtraction
#     *: Multiplcation
#     /:Division
#     //:Floor division
#     %:Modulus (Remainder)
#     **:Exponent (Power)
#     +=: Adds right operand to the left operand and assigns the result to the left operand.
#     -=: Subtracts the right operand from the left operand and assigns the result to the left operand.
#     *=: Multiplies the left operand by the right operand and assigns the result to the left operand.
#     /=: Divides the left operand by the right operand and assigns the result to the left operand.
#     %=: Takes modulus of left operand by right operand and assigns the result to the left operand.

# %%
# x=3
# x= 3+3
# x=3-3
# x= 3*2
# x= 3/2
# x= 11//2
# x= 11%3

x= 3**2
print(x)
# Out:
# 9

# %%
x=3
# x+=4
x= x+4
print(x)
# Out:
# 7

# %%
print("*"*60)
print("********** welcome to manipal hospital *******")
print("********* enter to patient details ********")
patient_name= input("enter patient name:  ")
age= int(input("enter age:  "))
weight= float(input("enter weight(kg):  "))
height= float(input("enter height(float):  "))
phone_number=input("enter phone no: ")
address= input("Enter address: ")

has_insurance= input("Do you have insurance (yes/no): ")
print("\n******* Patient details *********")
print(f"""
Name : {patient_name}
Age: {age}
Weight:{weight} kg
Height:{height} ft
phone number:{phone_number}
Addres :{address}
Has insurance :{has_insurance}
""")
# Out:
# ************************************************************
# ********** welcome to manipal hospital *******
# ********* enter to patient details ********
#
# ******* Patient details *********
#
# Name : riya
# Age: 20
# Weight:45.0 kg
# Height:5.0 ft
# phone number:1999900
# Addres :xyz
# Has insurance :yes
